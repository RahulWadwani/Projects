# %%
import pyarrow.parquet as pq
import pandas as pd 
import numpy as np

# %%
gtrip = pq.read_table('green_tripdata_2023-03.parquet')
gtrip = gtrip.to_pandas()

# %%
gtrip
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2023-03-01 00:25:10   2023-03-01 00:35:47                  N
# 1             2  2023-03-01 00:14:29   2023-03-01 00:25:04                  N
# 2             2  2023-03-01 00:14:29   2023-03-01 00:25:04                  N
# 3             2  2023-02-28 22:59:46   2023-02-28 23:08:38                  N
# 4             2  2023-03-01 00:54:03   2023-03-01 01:03:14                  N
# ...         ...                  ...                   ...                ...
# 72039         2  2023-03-31 23:33:00   2023-03-31 23:45:00               None
# 72040         2  2023-03-31 23:27:00   2023-03-31 23:53:00               None
# 72041         2  2023-03-31 23:09:00   2023-03-31 23:40:00               None
# 72042         2  2023-03-31 23:39:00   2023-04-01 00:01:00               None
# 72043         2  2023-03-31 23:38:00   2023-03-31 23:53:00               None
#
# ...

# %%
ytrip = pq.read_table('yellow_tripdata_2023-03.parquet')
ytrip = ytrip.to_pandas()
ytrip
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2023-03-01 00:06:43   2023-03-01 00:16:43              1.0
# 1               2  2023-03-01 00:08:25   2023-03-01 00:39:30              2.0
# 2               1  2023-03-01 00:15:04   2023-03-01 00:29:26              0.0
# 3               1  2023-03-01 00:49:37   2023-03-01 01:01:05              1.0
# 4               2  2023-03-01 00:08:04   2023-03-01 00:11:06              1.0
# ...           ...                  ...                   ...              ...
# 3403761         2  2023-03-31 23:24:25   2023-03-31 23:40:54              NaN
# 3403762         2  2023-03-31 23:24:50   2023-04-01 00:04:12              NaN
# 3403763         2  2023-03-31 23:26:31   2023-03-31 23:49:39              NaN
# 3403764         2  2023-03-31 23:07:51   2023-03-31 23:15:56              NaN
# 3403765         2  2023-03-31 23:26:12   2023-03-31 23:31:47              NaN
#
# ...

# %%
gtrip.isnull().sum()  # check for null values in green tripdata
# Out:
# VendorID                     0
# lpep_pickup_datetime         0
# lpep_dropoff_datetime        0
# store_and_fwd_flag        4537
# RatecodeID                4537
# PULocationID                 0
# DOLocationID                 0
# passenger_count           4537
# trip_distance                0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# ehail_fee                72044
# improvement_surcharge        0
# total_amount                 0
# payment_type              4537
# trip_type                 4544
# congestion_surcharge      4537
# dtype: int64

# %%
ytrip.isnull().sum()   # check for null values in yellow tripdata
# Out:
# VendorID                     0
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# passenger_count          87619
# trip_distance                0
# RatecodeID               87619
# store_and_fwd_flag       87619
# PULocationID                 0
# DOLocationID                 0
# payment_type                 0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# improvement_surcharge        0
# total_amount                 0
# congestion_surcharge     87619
# Airport_fee              87619
# dtype: int64

# %%
# describe green and yellow trip data

ytrip.describe()
# Out:
#            VendorID  passenger_count  trip_distance    RatecodeID  \
# count  3.403766e+06     3.316147e+06   3.403766e+06  3.316147e+06
# mean   1.725320e+00     1.351417e+00   3.903871e+00  1.623961e+00
# std    4.588677e-01     8.861919e-01   1.916866e+02  7.358691e+00
# min    1.000000e+00     0.000000e+00   0.000000e+00  1.000000e+00
# 25%    1.000000e+00     1.000000e+00   1.050000e+00  1.000000e+00
# 50%    2.000000e+00     1.000000e+00   1.790000e+00  1.000000e+00
# 75%    2.000000e+00     1.000000e+00   3.380000e+00  1.000000e+00
# max    6.000000e+00     9.000000e+00   2.169870e+05  9.900000e+01
#
#        PULocationID  DOLocationID  payment_type   fare_amount         extra  \
# count  3.403766e+06  3.403766e+06  3.403766e+06  3.403766e+06  3.403766e+06
# mean   1.654540e+02  1.641003e+02  1.187310e+00  1.890845e+01  1.629128e+00
# std    6.373958e+01  6.967282e+01  5.334025e-01  1.825637e+01  1.842778e+00
# ...

# %%
gtrip.describe()
# Out:
#            VendorID    RatecodeID  PULocationID  DOLocationID  \
# count  72044.000000  67507.000000  72044.000000  72044.000000
# mean       1.865443      1.145703     98.437413    137.613556
# std        0.341252      1.225735     60.481870     76.169705
# min        1.000000      1.000000      1.000000      1.000000
# 25%        2.000000      1.000000     74.000000     74.000000
# 50%        2.000000      1.000000     75.000000    138.000000
# 75%        2.000000      1.000000    129.000000    216.000000
# max        2.000000     99.000000    265.000000    265.000000
#
#        passenger_count  trip_distance   fare_amount         extra  \
# count     67507.000000   72044.000000  72044.000000  72044.000000
# mean          1.286844      12.449511     17.018203      0.878109
# std           0.923652     641.094653     13.832399      1.297642
# min           0.000000       0.000000   -115.000000     -5.000000
# 25%           1.000000       1.100000      9.300000      0.000000
# ...
