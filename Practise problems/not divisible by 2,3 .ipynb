# %%
for i in range(0,21):
    if i % 2 != 0 and i % 3 != 0 :
        print(i)
# Out:
# 1
# 5
# 7
# 11
# 13
# 17
# 19

# %%
pip freeze
# Out:
# absl-py==1.0.0
# anyio==3.5.0
# apiai==1.2.3
# appdirs==1.4.4
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# arrow==1.2.2
# asgiref==3.5.0
# asttokens==2.0.5
# astunparse==1.6.3
# async-generator==1.10
# atomicwrites==1.4.0
# attrs==21.4.0
# audioread==2.1.9
# awscli==1.22.46
# Babel==2.9.1
# backcall==0.2.0
# bash==0.6
# beautifulsoup4==4.10.0
# beeware==0.3.0
# binaryornot==0.4.4
# black==21.12b0
# bleach==4.1.0
# boto3==1.20.46
# botocore==1.23.46
# briefcase==0.3.6
# cachetools==5.0.0
# certifi==2021.10.8
# cffi==1.15.0
# chardet==4.0.0
# charset-normalizer==2.0.9
# click==7.1.2
# cmake==3.22.2
# colorama==0.4.3
# commonmark==0.9.1
# comtypes==1.1.9
# constant==0.0.4
# cookiecutter==1.7.3
# cryptography==37.0.4
# cssutils==2.3.0
# cvlib==0.2.6
# cycler==0.10.0
# Cython==0.29.28
# debugpy==1.5.1
# decorator==5.1.1
# defusedxml==0.7.1
# distlib==0.3.1
# Django==4.0.3
# docker==5.0.3
# docutils==0.15.2
# entrypoints==0.3
# et-xmlfile==1.1.0
# executing==0.8.2
# ...
