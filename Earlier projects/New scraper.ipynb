# %%
import requests 
from bs4 import BeautifulSoup

# %%
topic = input('Enter the topic you want to search about:')
link = 'https://www.google.com/search?q='+topic.replace(' ','+')+'&tbm=nws'
# Out:
# Enter the topic you want to search about:bit coin

# %%
res = requests.get(link).text
soup = BeautifulSoup(res,'html.parser')
news_topic = [news.text for news in soup.find_all('a')[17:-7]]
news_links = [news for news in soup.find_all('a')[7:-88]]

# %%
# Out:
# ['Google',
#  '×',
#  '×',
#  '×',
#  '×',
#  '',
#  'Please click here if you are not redirected within a few seconds.',
# ...

# %%
https://cointelegraph.com/news/bitcoin-bears-could-face-440m-loss-in-friday-s-options-expiry
